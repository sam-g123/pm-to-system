# %% [markdown]
# <a href="https://colab.research.google.com/github/sam-g123/pm-to-system/blob/scheduling/productivity%20management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sam-g123/pm-to-system.git
# Out:
# Cloning into 'pm-to-system'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 172 (delta 40), reused 154 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (172/172), 25.23 MiB | 36.08 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# %cd pm-to-system
# Out:
# /content/pm-to-system/pm-to-system

# %%
# !git checkout scheduling
# Out:
# Branch 'scheduling' set up to track remote branch 'scheduling' from 'origin'.
# Switched to a new branch 'scheduling'

# %%
# !python your_script_name.py
# Out:
# python3: can't open file '/content/pm-to-system/pm-to-system/your_script_name.py': [Errno 2] No such file or directory

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "/content/pm-to-system/pm-to-system/main.py", line 11, in <module>
#     from PyQt5.QtWidgets import QApplication, QWidget # Import QWidget for type hinting
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'PyQt5'

# %%
# !python install_requirements.py
# Out:
# Reading requirements from requirements.txt...
# 🔗 Detected find-links URL: https://download.pytorch.org/whl/torch_stable.html
#
# Starting installation process...
# ▶️ Installing absl-py normally
# /usr/bin/python3.10: No module named pip
# Traceback (most recent call last):
#   File "/content/pm-to-system/pm-to-system/install_requirements.py", line 98, in <module>
#     main()
#   File "/content/pm-to-system/pm-to-system/install_requirements.py", line 93, in main
#     install_requirements(reqs)
#   File "/content/pm-to-system/pm-to-system/install_requirements.py", line 81, in install_requirements
#     subprocess.run(command, check=True)
#   File "/usr/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['python3.10', '-m', 'pip', 'install', '--find-links', 'https://download.pytorch.org/whl/torch_stable.html', 'absl-py==2.3.1']' returned non-zero exit status 1.
